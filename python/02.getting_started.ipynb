# %% [markdown]
# # Current Python version is this
# ![image.png](attachment:image.png)

# %% [markdown]
# # From Command Prompt lets install the same
# # Before that lets check the current version in the system
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lets check tha available version from the command prompt
# # winget search Python
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lets Install the desired version, Lets install the latest one
# # Command
# ##  winget install --id Python.Python.3.13 -e
# # After that check the verion by listing the installed versions in the system
# # Command
# ## py --list
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Now lets setup the Virtual env with our desired version
# # command
# ## py -3.13 -m venv demo
# # And Activate it
# # Command
# ## .\demo\Scripts\activate.bat
#
# ![image.png](attachment:image.png)

# %%
name = input("What is your name : ? ")
print("Welcome {}".format(name))
# Out:
# Welcome pritam
