# %% [markdown]
# # File Operation- Read And Write Files
# File handling is a crucial part of any programming language.
# Python provides built-in functions and methods to read from and write to files, both text and binary.
#  This lesson will cover the basics of file handling, including reading and writing text files and binary files.

# %%
### Read a Whole File

with open('source.txt','r') as file: # which file and r : means in read mode
    content=file.read() # Reading the content
    print(content) # Print
# Out:
# This is my source file
# which will be copied.
# All content of this file will be copied to the
# destination file.

# %%
## Read a file line by line
with open('source.txt','r') as file:
    line_no = 1
    for line in file:
        print("Line no {} is : {}".format(line_no,line.strip())) ## strip() removes the newline character
        line_no+=1
# Out:
# Line no 1 is : This is my source file
# Line no 2 is : which will be copied.
# Line no 3 is : All content of this file will be copied to the
# Line no 4 is : destination file.

# %%
## Writing a file(Overwriting)

with open('source.txt','w') as file: # now in w : write mode
    file.write('Hello World!\n') # Adding new line with a new line ( \n was removed by strip() )
    file.write('this is a new line.\n')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Content is overwritten

# %%
## Write a file(without Overwriting)
with open('source.txt','a') as file: # Apprnd mode means apped and write
    file.write("Append operation taking place!\n")
    file.write("Appended :) \n")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
### Writing a list of lines to a file
lines=['First line \n','Second line \n','Third line\n']
with open('source.txt','a') as file:
    file.writelines(lines)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
### Binary Files
## In this files we update the bytes 

# Writing to a binary file
data = b'\x00\x01\x02\x03\x04'
with open('example.bin', 'wb') as file: # wb : write byte / rb : read byte
    file.write(data)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Reading a binary file
with open('example.bin', 'rb') as file:
    content = file.read()
    print(content)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
### Read the content from a source text fiile and write to a destination text file
# Copying a text file
with open('source.txt', 'r') as source_file:
    content = source_file.read()

with open('destinations.txt', 'w') as destination_file:
    destination_file.write(content)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Read a text file and count the number of lines, words, and characters.
# Counting lines, words, and characters in a text file
def count_text_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        line_count = len(lines)
        word_count = sum(len(line.split()) for line in lines)
        char_count = sum(len(line) for line in lines)
    return line_count, word_count, char_count

file_path = 'source.txt'
lines, words, characters = count_text_file(file_path)
print(f'Lines: {lines}, Words: {words}, Characters: {characters}')
# Out:
# Lines: 7, Words: 19, Characters: 113

# %% [markdown]
# ### The w+ mode in Python is used to open a file for both reading and writing. If the file does not exist, it will be created. If the file exists, its content is truncated (i.e., the file is overwritten).

# %%
### Writing and then reading a file

with open('source.txt','w+') as file: # writing w+ : means write 
    file.write("Hello world of Python \n")
    file.write("This is a new line \n")

    ## Move the file cursor to the beginning so we can read from other line, 0 : first line
    file.seek(0)

    ## Read the content of the file
    content=file.read()
    print(content)
# Out:
# Hello world of Python
# This is a new line

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open('source.txt','w+') as file: # writing w+ : means write 
    file.write("Hello world of Python \n")
    file.write("This is a new line \n")

    ## Move the file cursor to the beginning so we can read from other line, 0 : first line
    # file.seek(0) # commented

    ## Read the content of the file
    content1=file.read()
    print(content1)

# %% [markdown]
# # Nothing to display as the pointer after writting is in the last line

# %%
with open('source.txt','w+') as file: # writing w+ : means write 
    file.write("Hello world of Python \n")
    file.write("This is a new line \n")

    ## Move the file cursor to the beginning so we can read from other line, 0 : first line
    file.seek(1) # commented

    ## Read the content of the file
    content1=file.read()
    print(content1)
# Out:
# ello world of Python
# This is a new line

# %%
with open('source.txt','w+') as file: # writing w+ : means write 
    file.write("Hello world of Python \n")
    file.write("This is a new line \n")

    ## Move the file cursor to the beginning so we can read from other line, 0 : first line
    file.seek(3) # commented

    ## Read the content of the file
    content1=file.read()
    print(content1)
# Out:
# lo world of Python
# This is a new line

# %%
with open('source.txt','w+') as file: # writing w+ : means write 
    file.write("Hello world of Python \n")
    file.write("This is a new line \n")

    ## Move the file cursor to the beginning so we can read from other line, 0 : first line
    file.seek(0) # fromZERO, th index

    ## Read the content of the file
    content1=file.read()
    print(content1)
# Out:
# Hello world of Python
# This is a new line
