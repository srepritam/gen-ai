# %% [markdown]
# # Different Ways to create environment variable
# ## Way 1
# # Command
# ## python -n venv test ( Venev means my virtual environment and test is the directory where I want to create the environment)
# # To activate : command
# ## test\Scripts\activate
# ![image.png](attachment:image.png)

# %% [markdown]
# # Under the test directory as of now these are the libs
# ![image.png](attachment:image.png)

# %% [markdown]
# # If we need some packages inside this virtual env then we need to install those
# # For Example
# # Command: pip install requests
# ![image.png](attachment:image.png)
# # And we will see that is installed inside the Lib Directory under our venv directory
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # If we need many other pacakges for our project ( As we are creating the venev for a particular project)
# # We can make use of requirements.txt

# %% [markdown]
# ## Now lets check the python version inside this venv
# ![image.png](attachment:image.png)

# %% [markdown]
# # way 2
# ## We need to install virtualenv
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # command : virtualenv -p python3 my_env
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # To activate the virtual env
# ![image.png](attachment:image.png)

# %% [markdown]
# # To Deactivate
# ![image.png](attachment:image.png)

# %% [markdown]
# # Way 3
# # Download and Install Anaconda
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Now check the python version in the system
# ![image.png](attachment:image.png)
#
# # And lets say we need a specific version of python in our virtual environment

# %% [markdown]
# # If we get this error
# ![image.png](attachment:image.png)

# %% [markdown]
# # Find the Anaconda instalation path
# ![image.png](attachment:image.png)

# %% [markdown]
# # Edit the System Environment Variable
# ![image.png](attachment:image.png)

# %% [markdown]
# # Edit System Variable PATH
# ![image.png](attachment:image.png)

# %% [markdown]
# # Add the PATH
# ![image.png](attachment:image.png)

# %% [markdown]
# # Check the conda version
# ![image.png](attachment:image.png)

# %% [markdown]
# # In VS Code if we cannot see the conda version then Restart VScode. Then check
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# # Creating a virtual environment in the conda directory using conda
# ## It will install the required package
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # We can activate an deactivate likewise
# ![image.png](attachment:image.png)

# %% [markdown]
# # Later we wil work in this ENvironment
